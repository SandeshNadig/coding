# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]

plt.plot(x)
plt.xticks([5,10,15,20])
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]

plt.plot(x)
plt.xticks([5,10,15,20])
plt.grid(True)
plt.show()
